# %% [markdown]
# ### Script purpose.
#
# This script generates user dictionaries for Python package _jieba_.
# Part-of-speech tag is using file `POS_tag.md`
#
# Cleaning data fields.
# - Strip whitespaces.
# - Skip null values, e.g., "[未詳]", str(s)!="None".
# - Normalize text from full-width to half-width.
# - Split string containing multiple values (use of reexp intead of split).
#
# TODO:
#
# - [X] - Wrap the data cleaning procedures into function.
# - [] - Unify the data cleaning in all sections.
# - [] - Test on 全宋文墓誌铭.

# %%
import sqlite3
import pandas as pd
import re
import itertools as it
import unicodedata

# %%
# Init with sqlite file.
sqlite_file='../data_raw/sqlite_20180302.db'
conn = sqlite3.connect(sqlite_file)

# value_clean(string, sep_char=',')
def value_clean(string, sep_char=','):
    if str(string)!="[未詳]" and str(string)!='' and str(string)!='None' and str(string)!='nan':
        string=''.join(string.split())
        string=unicodedata.normalize('NFKC', string)
        return re.findall(r"[\w]+", string)
    else:
        return 'NA'

# %% [markdown]
# ### People Names.

# %%
# Read tables.
df_biog_main=pd.read_sql_query("SELECT * FROM BIOG_MAIN", conn)
df_altname_data=pd.read_sql_query("SELECT * FROM ALTNAME_DATA", conn)

print(len(set(df_altname_data['c_alt_name_chn'])), 
      len(set(df_biog_main['c_name_chn'])), 
      len(set(df_altname_data['c_alt_name_chn']))+len(set(df_biog_main['c_name_chn'])))
# Out:
# 71614 321207 392821

# %%
# Merge ang tag the dict.
df_name=pd.DataFrame(pd.Series(list(set(df_biog_main['c_name_chn']))), columns=['name'])
df_name['pos']='nr'
df_name['name']=[re.sub(r'\(.+', '', s) for s in df_name['name']]

# Save to file.
df_name.to_csv('../data_build/cn_traditional_jieba/nr_nra_dict_CBDB.txt', 
               sep=' ', index=False, header=False)

# %% [markdown]
# ### Address.

# %%
# Read tables.
# Merge data.
addresses_set=set(''.join(s.split()) for s in pd.read_sql_query("SELECT * FROM ADDRESSES", conn)['c_name_chn'] if str(s)!='None' and str(s)!='[未詳]' and str(s)!='')
place_codes_set=set(''.join(s.split()) for s in pd.read_sql_query("SELECT * FROM PLACE_CODES", conn)['c_name_chn'] if str(s)!='None' and str(s)!='[未詳]' and str(s)!='')
ns_set=place_codes_set.union(addresses_set)
print(len(addresses_set), len(place_codes_set), len(ns_set))
# Out:
# 9773 2491 9793

# %%
pd.DataFrame([[s, 'ns'] for s in ns_set], 
             columns=['name', 'pos']).to_csv('../data_build/cn_traditional_jieba/ns_dict_CBDB.txt', 
                                             sep=' ', index=False, header=False)

# %% [markdown]
# #### Song addresses.

# %%
df_song_addr=pd.read_sql_query("SELECT * FROM ADDRESSES", conn)
df_song_addr=df[(df.belongs1_Name=='宋朝')|(df.belongs2_Name=='宋朝')|(df.belongs3_Name=='宋朝')|(df.belongs4_Name=='宋朝')|(df.belongs5_Name=='宋朝')]
df_song_addr['pos']='ns'
# Out:
# /tikal/ji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_song_addr=df_song_addr[['c_name_chn', 'pos']].drop_duplicates() # Drop duplicates.
# Handle order effect while matching. See notes in qsw_sent_comp script.
df_song_addr.index=df_song_addr['c_name_chn'].str.len()
df_song_addr=df_song_addr.sort_index(ascending=False).reset_index(drop=True)

# %%
df_song_addr.to_csv('../data_build/cn_traditional_jieba/song_ns_dict.csv', sep='\t', index=False, header=False)

# %% [markdown]
# ### Office Title.

# %%
# Read tables.
df_office_codes=pd.read_sql_query("SELECT * FROM OFFICE_CODES", conn)
df_office_categories=pd.read_sql_query("SELECT * FROM OFFICE_CATEGORIES", conn)

# %%
# Clean data.
office_set=set([s for s in df_office_codes['c_office_chn']])
office_alt_list=[]
for office_alt in df_office_codes['c_office_chn_alt']:
    if office_alt!=None and str(office_alt)!='':
        office_alt_list+=office_alt.split(';')
office_set=office_set.union(set([s for s in office_alt_list if s!='']))
office_cata_set=set(s for s in df_office_categories['c_category_desc_chn'])

# %%
# Merge ang tag the dict.
df_no_noc=pd.DataFrame([[s, 'no'] for s in office_set]+[[s, 'noc'] for s in office_cata_set],
                      columns=['name', 'pos'])
# Save to file.
df_no_noc.to_csv('../data_build/cn_traditional_jieba/no_noc_dict_CBDB.txt', 
                  sep=' ', index=False, header=False)

# %% [markdown]
# #### Song office titles.

# %%
df_office_codes_song=df_office_codes[df_office_codes['c_dy']==15]
df_office_codes_song.sample(3)
# Out:
#       tts_sysno  c_office_id  c_dy                 c_office_pinyin  \
# 4145     4146.0         4703    15              tai fu si di er an
# 5451     5452.0         6010    15             tai shang huang hou
# 4379     4380.0         4937    15  xi jing liu shou si yu shi tai
#
#      c_office_chn                                c_office_pinyin_alt  \
# 4145       太府寺第二案                                               None
# 5451         太上皇后                                               None
# 4379     西京留守司御史臺  liu tai;xi jing liu tai;xi du liu tai;xi jing ...
#
#              c_office_chn_alt c_office_trans c_office_trans_alt  c_source  \
# 4145                     None           None               None       NaN
# 5451                     None           None               None       NaN
# 4379  留臺;西京留臺;西都留臺;西京留司御史臺;外臺           None               None       NaN
#
#      c_pages c_notes c_category_1 c_category_2 c_category_3 c_category_4  \
# 4145    None    None           機構         太府寺門         None         None
# 5451    None    None         None         None         None         None
# 4379    None    None           機構         御史臺門         None         None
#
#       c_office_id_old
# 4145              0.0
# 5451              0.0
# 4379              0.0

# %%
song_no_set=set(it.chain(*df_office_codes_song['c_office_chn'].apply(value_clean).values)).union(set(it.chain(*df_office_codes_song['c_office_chn_alt'].apply(value_clean).values)))

# %%
df_song_no=pd.DataFrame(sorted([(s, len(s), 'no') for s in song_no_set if s!='NA'], key=lambda x:x[1], reverse=True),
                        columns=['name', 'len', 'pos']
                       ).drop('len', axis=1)

# %%
df_song_no.to_csv('../data_build/cn_traditional_jieba/song_no_dict.csv', 
                  sep='\t', index=False, header=False)

# %% [markdown]
# ### Time.

# %%
# Read tables.
#df_dyna=pd.read_sql_query("SELECT * FROM DYNASTIES", conn)
df_reign=pd.read_sql_query("SELECT * FROM NIAN_HAO", conn)

# %%
# Get data.
dynasty_set=set(df_reign['c_dynasty_chn'])
reign_set=set(df_reign['c_nianhao_chn'])

# %%
# Merge ang tag the dict.
df_td_tr=pd.DataFrame([[s, 'td'] for s in dynasty_set]+[[s, 'tr'] for s in reign_set],
                      columns=['name', 'pos'])
# Save to file.
df_td_tr.to_csv('../data_build/cn_traditional_jieba/td_tr_dict_CBDB.txt', 
                  sep=' ', index=False, header=False)

# %% [markdown]
# ### Kinship title.

# %%
# Read tables.
df_kin=pd.read_sql_query("SELECT * FROM KINSHIP_CODES", conn)

# %%
# Get and clean data.
kin_list=[''.join(s.split()) for s in set(it.chain(*[s.split(';') for s in df_kin['c_kinrel_chn'] if s!=None]))]

# %%
# Merge ang tag the dict.
df_nk=pd.DataFrame([(s, 'nk') for s in kin_list], columns=['name', 'pos'])

# %%
# Save to file.
df_nk.to_csv('../data_build/cn_traditional_jieba/nk_dict_CBDB.txt', 
             sep=' ', index=False, header=False)

# %% [markdown]
# ### Institution names.

# %%
# Read tables.
inst_nm_set=set(it.chain(*[value_clean(s) for s in 
                           pd.read_sql_query("SELECT * FROM SOCIAL_INSTITUTION_NAME_CODES", conn)['c_inst_name_hz']]))

# %%
# Clean data and save to dict file.
pd.DataFrame([[s, 'nt'] for s in inst_nm_set], 
             columns=['name', 'pos']).to_csv('../data_build/cn_traditional_jieba/nt_dict_CBDB.txt',
                                             sep=' ', index=False, header=False)

# %% [markdown]
# ### TESTING AREA.

# %%
pd.read_sql_query("SELECT * FROM FOREIGNKEYS", conn)
# Out:
#                     AccessTblNm                   AccessFldNm  \
# 0             ADDR_BELONGS_DATA                     c_addr_id
# 1             ADDR_BELONGS_DATA                  c_belongs_to
# 2             ADDR_BELONGS_DATA                      c_source
# 3                  altname_data          c_alt_name_type_code
# 4                  altname_data                    c_personid
# 5                  altname_data                      c_source
# 6           ASSOC_CODE_TYPE_REL                  c_assoc_code
# 7           ASSOC_CODE_TYPE_REL               c_assoc_type_id
# 8                   ASSOC_CODES                 c_assoc_pair2
# 9                    assoc_data                     c_addr_id
# 10                   assoc_data            c_assoc_claimer_id
# 11                   assoc_data                  c_assoc_code
# 12                   assoc_data                c_assoc_day_gz
# 13                   assoc_data                    c_assoc_id
# 14                   assoc_data              c_assoc_kin_code
# 15                   assoc_data                c_assoc_kin_id
# 16                   assoc_data               c_assoc_nh_code
# 17                   assoc_data                 c_assoc_range
# 18                   assoc_data              c_inst_name_code
# 19                   assoc_data  c_inst_name_code,c_inst_code
# 20                   assoc_data                    c_kin_code
# 21                   assoc_data                      c_kin_id
# 22                   assoc_data               c_litgenre_code
# 23                   assoc_data               c_occasion_code
# 24                   assoc_data                    c_personid
# 25                   assoc_data                      c_source
# 26                   ASSOC_DATA           c_tertiary_personid
# 27                   assoc_data                  c_topic_code
# 28               biog_addr_data                     c_addr_id
# 29               biog_addr_data                   c_addr_type
# ..                          ...                           ...
# 152    SOCIAL_INSTITUTION_CODES              c_inst_type_code
# 153    SOCIAL_INSTITUTION_CODES                      c_source
# 154        STATUS_CODE_TYPE_REL                 c_status_code
# 155        STATUS_CODE_TYPE_REL            c_status_type_code
# 156                 status_data                  c_fy_nh_code
# 157                 status_data                    c_fy_range
# 158                 status_data                  c_ly_nh_code
# 159                 status_data                    c_ly_range
# 160                 status_data                    c_personid
# 161                 status_data                      c_source
# 162                 status_data                 c_status_code
# 163  TEXT_BIBLCAT_CODE_TYPE_REL               c_text_cat_code
# 164  TEXT_BIBLCAT_CODE_TYPE_REL            c_text_cat_type_id
# 165                  TEXT_CODES               c_bibl_cat_code
# 166                  text_codes                      c_extant
# 167                  text_codes                 c_pub_country
# 168                  text_codes                      c_pub_dy
# 169                  text_codes                 c_pub_nh_code
# 170                  text_codes              c_pub_range_code
# 171                  text_codes                      c_source
# 172                  text_codes                c_text_country
# 173                  text_codes                     c_text_dy
# 174                  text_codes                c_text_nh_code
# 175                  text_codes             c_text_range_code
# 176                   TEXT_DATA                     c_nh_code
# 177                   TEXT_DATA                    c_personid
# 178                   TEXT_DATA                  c_range_code
# 179                   TEXT_DATA                     c_role_id
# 180                   TEXT_DATA                      c_source
# 181                   TEXT_DATA                      c_textid
#
#                         ForeignKey ForeignKeyBaseField  \
# 0                       ADDR_CODES           c_addr_id
# 1                       ADDR_CODES           c_addr_id
# 2                       TEXT_CODES            c_textid
# 3                    ALTNAME_CODES    c_name_type_code
# 4                        BIOG_MAIN          c_personid
# 5                       TEXT_CODES            c_textid
# 6                      ASSOC_CODES        c_assoc_code
# 7                      ASSOC_TYPES     c_assoc_type_id
# 8                      ASSOC_CODES        c_assoc_code
# 9                       ADDR_CODES           c_addr_id
# 10                       BIOG_MAIN          c_personid
# 11                     ASSOC_CODES        c_assoc_code
# 12                    GANZHI_CODES       c_ganzhi_code
# 13                       BIOG_MAIN          c_personid
# 14                   KINSHIP_CODES          c_kin_code
# 15                       BIOG_MAIN          c_personid
# 16                        nian_hao        c_nianhao_id
# 17                year_range_codes        c_range_code
# 18   SOCIAL_INSTITUTION_NAME_CODES    c_inst_name_code
# 19        SOCIAL_INSTITUTION_CODES         c_inst_code
# 20                   KINSHIP_CODES           c_kincode
# 21                       BIOG_MAIN          c_personid
# 22             literarygenre_codes    c_lit_genre_code
# 23                  OCCASION_CODES     c_occasion_code
# 24                       BIOG_MAIN          c_personid
# 25                      TEXT_CODES            c_textid
# 26                       BIOG_MAIN          c_personid
# 27            SCHOLARLYTOPIC_CODES        c_topic_code
# 28                      ADDR_CODES           c_addr_id
# 29                 BIOG_ADDR_CODES         c_addr_type
# ..                             ...                 ...
# 152       SOCIAL_INSTITUTION_TYPES    c_inst_type_code
# 153                     TEXT_CODES            c_textid
# 154                   STATUS_CODES       c_status_code
# 155                   STATUS_TYPES  c_status_type_code
# 156                       nian_hao        c_nianhao_id
# 157               year_range_codes        c_range_code
# 158                       nian_hao        c_nianhao_id
# 159               year_range_codes        c_range_code
# 160                      BIOG_MAIN          c_personid
# 161                     TEXT_CODES            c_textid
# 162                   STATUS_CODES       c_status_code
# 163             TEXT_BIBLCAT_CODES     c_text_cat_code
# 164             TEXT_BIBLCAT_TYPES  c_text_cat_type_id
# 165             TEXT_BIBLCAT_CODES     c_text_cat_code
# 166                   EXTANT_CODES       c_extant_code
# 167                  COUNTRY_CODES      c_country_code
# 168                      DYNASTIES                c_dy
# 169                       NIAN_HAO        c_nianhao_id
# 170               YEAR_RANGE_CODES        c_range_code
# 171                     TEXT_CODES            c_textid
# 172                  COUNTRY_CODES      c_country_code
# 173                      DYNASTIES                c_dy
# 174                       NIAN_HAO        c_nianhao_id
# 175               YEAR_RANGE_CODES        c_range_code
# 176                       NIAN_HAO      c_nianhao_code
# 177                      BIOG_MAIN          c_personid
# 178               YEAR_RANGE_CODES        c_range_code
# 179                TEXT_ROLE_CODES           c_role_id
# 180                     TEXT_CODES            c_textid
# 181                     TEXT_CODES            c_textid
#
#                          FKString  \
# 0                       c_addr_id
# 1                       c_addr_id
# 2                        c_textid
# 3                c_name_type_code
# 4                      c_personid
# 5                        c_textid
# 6                    c_assoc_code
# 7                 c_assoc_type_id
# 8                    c_assoc_code
# 9                       c_addr_id
# 10                     c_personid
# 11                   c_assoc_code
# 12                  c_ganzhi_code
# 13                     c_personid
# 14                      c_kincode
# 15                     c_personid
# 16                   c_nianhao_id
# 17                   c_range_code
# 18               c_inst_name_code
# 19   c_inst_name_code,c_inst_code
# 20                      c_kincode
# 21                     c_personid
# 22               c_lit_genre_code
# 23                c_occasion_code
# 24                     c_personid
# 25                       c_textid
# 26                     c_personid
# 27                   c_topic_code
# 28                      c_addr_id
# 29                    c_addr_type
# ..                            ...
# 152              c_inst_type_code
# 153                      c_textid
# 154                 c_status_code
# 155            c_status_type_code
# 156                  c_nianhao_id
# 157                  c_range_code
# 158                  c_nianhao_id
# 159                  c_range_code
# 160                    c_personid
# 161                      c_textid
# 162                 c_status_code
# 163               c_text_cat_code
# 164            c_text_cat_type_id
# 165               c_text_cat_code
# 166                 c_extant_code
# 167                c_country_code
# 168                          c_dy
# 169                  c_nianhao_id
# 170                  c_range_code
# 171                      c_textid
# 172                c_country_code
# 173                          c_dy
# 174                  c_nianhao_id
# 175                  c_range_code
# 176                  c_nianhao_id
# 177                    c_personid
# 178                  c_range_code
# 179                     c_role_id
# 180                      c_textid
# 181                      c_textid
#
#                                                 FKName  skip IndexOnField  \
# 0                                 ADDR_BELONGS_ADDR_ID     1  Primary Key
# 1                               ADDR_BELONGS_BELONG_ID     0  Primary Key
# 2                               ADDR_BELONGS_TEXT_CODE     0         None
# 3                           ALTNAME_DATA_ALTNAME_CODES     1  Primary Key
# 4                               ALTNAME_DATA_PERSON_ID     1  Primary Key
# 5                               ALTNAME_DATA_TEXT_CODE     1         None
# 6                       ASSOC_CODE_TYPE_REL_ASSOC_CODE     0  Primary Key
# 7                       ASSOC_CODE_TYPE_REL_ASSOC_TYPE     0  Primary Key
# 8                               ASSOC_CODES_ASSOC_PAIR     0         None
# 9                                   ASSOC_DATA_ADDR_ID     1         None
# 10                               ASSOC_DATA_CLAIMER_ID     0         None
# 11                               ASSOC_DATA_ASSOC_CODE     1      Primary
# 12                                   ASSOC_DATA_GANZHI     0         None
# 13                                 ASSOC_DATA_ASSOC_ID     1      Primary
# 14                           ASSOC_DATA_ASSOC_KIN_CODE     1      Primary
# 15                             ASSOC_DATA_ASSOC_KIN_ID     1      Primary
# 16                                 ASSOC_DATA_nian_hao     0         None
# 17                          ASSOC_DATA_year_range_code     0         None
# 18             ASSOC_DATA_SOCIAL_INSTITUTION_NAME_CODE     0         None
# 19                  ASSOC_DATA_SOCIAL_INSTITUTION_CODE     0         None
# 20                                 ASSOC_DATA_KIN_CODE     0      Primary
# 21                                   ASSOC_DATA_KIN_ID     1      Primary
# 22                       ASSOC_DATA_literarygenre_code     0         None
# 23                            ASSOC_DATA_OCCASION_CODE     0         None
# 24                                ASSOC_DATA_PERSON_ID     1      Primary
# 25                                ASSOC_DATA_TEXT_CODE     0         None
# 26                          ASSOC_DATA_THIRD_PERSON_ID     0         None
# 27                      ASSOC_DATA_SCHOLARLYTOPIC_CODE     0         None
# 28                            BIOG_ADDR_DATA_ADDR_CODE     1      Primary
# 29                       BIOG_ADDR_DATA_BIOG_ADDR_CODE     0      Primary
# ..                                                 ...   ...          ...
# 152  SOCIAL_INSTITUTION_CODES_SOCIAL_INSTITUTION_TY...     0         None
# 153            SOCIAL_INSTITUTION_CODES_SOURCE_TEXT_ID     0         None
# 154                   STATUS_CODE_TYPE_REL_STATUS_CODE     0  Primary Key
# 155                   STATUS_CODE_TYPE_REL_STATUS_TYPE     0  Primary Key
# 156                            STATUS_DATA_nian_hao_fy     0         None
# 157                     STATUS_DATA_year_range_code_fy     0         None
# 158                            STATUS_DATA_nian_hao_ly     0         None
# 159                     STATUS_DATA_year_range_code_ly     0         None
# 160                              STATUS_DATA_PERSON_ID     1  Primary Key
# 161                         STATUS_DATA_SOURCE_TEXT_ID     0         None
# 162                           STATUS_DATA_STATUS_CODES     1  Primary Key
# 163           TEXT_BIBLCAT_CODE_TYPE_REL_TEXT_CAT_CODE     1  Primary Key
# 164           TEXT_BIBLCAT_CODE_TYPE_REL_TEXT_CAT_TYPE     0  Primary Key
# 165                       TEXT_CODES_TEXT_BIBLCAT_CODE     1         None
# 166                             TEXT_CODES_EXTANT_CODE     0         None
# 167                        TEXT_CODES_COUNTRY_CODE_PUB     0         None
# 168                             TEXT_CODES_DYNASTY_PUB     0         None
# 169                            TEXT_CODES_NIAN_HAO_PUB     0         None
# 170                     TEXT_CODES_YEAR_RANGE_CODE_PUB     0         None
# 171                          TEXT_CODES_SOURCE_TEXT_ID     1         None
# 172                       TEXT_CODES_COUNTRY_CODE_TEXT     0         None
# 173                            TEXT_CODES_DYNASTY_TEXT     0         None
# 174                           TEXT_CODES_NIAN_HAO_TEXT     0         None
# 175                    TEXT_CODES_YEAR_RANGE_CODE_TEXT     0         None
# 176                                 TEXT_DATA_NIAN_HAO     0         None
# 177                                TEXT_DATA_PERSON_ID     1  Primary Key
# 178                          TEXT_DATA_YEAR_RANGE_CODE     0         None
# 179                           TEXT_DATA_TEXT_ROLE_CODE     0  Primary Key
# 180                           TEXT_DATA_SOURCE_TEXT_ID     0         None
# 181                                  TEXT_DATA_TEXT_ID     1  Primary Key
#
#     DataFormat  NULL_allowed
# 0         Long             0
# 1         Long             0
# 2         Long             1
# 3      Integer             0
# 4         Long             0
# 5         Long             1
# 6      Integer             0
# 7         Text             0
# 8      Integer             1
# 9         Long             1
# 10        Long             1
# 11        Long             0
# 12     Integer             1
# 13        Long             0
# 14        Long             0
# 15        Long             0
# 16     Integer             1
# 17     Integer             1
# 18     Integer             0
# 19     Integer             0
# 20        Long             0
# 21        Long             0
# 22     Integer             1
# 23     Integer             1
# 24        Long             0
# 25        Long             0
# 26        Long             1
# 27     Integer             1
# 28        Long             0
# 29     Integer             0
# ..         ...           ...
# 152    Integer             0
# 153       Long             0
# 154    Integer             0
# 155       Text             0
# 156    Integer             1
# 157    Integer             1
# 158    Integer             1
# 159    Integer             1
# 160       Long             0
# 161       Long             1
# 162    Integer             0
# 163    Integer             0
# 164       Text             0
# 165    Integer             1
# 166    Integer             1
# 167    Integer             1
# 168    Integer             1
# 169    Integer             1
# 170    Integer             1
# 171       Long             1
# 172    Integer             1
# 173    Integer             1
# 174    Integer             1
# 175    Integer             1
# 176    Integer             1
# 177       None             0
# 178    Integer             1
# 179    Integer             0
# 180       Long             0
# 181       None             0
#
# [182 rows x 10 columns]
