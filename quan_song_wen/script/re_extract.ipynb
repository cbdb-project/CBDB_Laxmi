# %%
from tqdm import tqdm
import pandas as pd
import re

# %%
df_sent_comp=pd.read_excel('../output/qsw_subtract.xlsx')

# %% [markdown]
# ### Male kinship extraction.

# %%
re_rule_list=[r'(三十一世祖|十八世祖|十六代祖|十五代祖|十三代祖|十二世祖|十二代祖|十一代祖|十一世祖|四代祖母|曾祖王父|外曾大父|外曾王父|外曾祖父|六代祖|十代祖|十世祖|九世祖|八世祖|七世祖|六世祖|五世祖|五代祖|四世祖|四代祖|高祖母|曾祖考|曾大父|大王父|曾王父|皇曾祖|曾大考|曾伯祖|曾叔祖|先祖考|先大父|先王父|皇祖考|伯祖父|叔祖父|從伯祖|再從伯|再從叔|再從舅|從伯父|從叔父|外祖父|外王父|外大父|外叔祖|外伯祖|再從舅|外伯父|外叔父|外大祖|外曾祖|遠祖|其先|高祖|曾祖|先祖|大父|王父|大考|從祖|族祖|伯祖|叔祖|皇考|先父|先考|先君|伯父|世父|叔父|族父|從伯|從父|從叔|從舅|外舅|母舅|外祖|從舅|外舅|祖|父|考|舅|舅)[諱|曰](.{0,2}?)/',
              r'^(三十一世祖|十八世祖|十六代祖|十五代祖|十三代祖|十二世祖|十二代祖|十一代祖|十一世祖|四代祖母|曾祖王父|外曾大父|外曾王父|外曾祖父|六代祖|十代祖|十世祖|九世祖|八世祖|七世祖|六世祖|五世祖|五代祖|四世祖|四代祖|高祖母|曾祖考|曾大父|大王父|曾王父|皇曾祖|曾大考|曾伯祖|曾叔祖|先祖考|先大父|先王父|皇祖考|伯祖父|叔祖父|從伯祖|再從伯|再從叔|再從舅|從伯父|從叔父|外祖父|外王父|外大父|外叔祖|外伯祖|再從舅|外伯父|外叔父|外大祖|外曾祖|遠祖|高祖|曾祖|先祖|大父|王父|大考|從祖|族祖|伯祖|叔祖|皇考|先父|先考|伯父|世父|叔父|族父|從伯|從父|從叔|從舅|外舅|母舅|外祖|從舅|外舅|祖|父|考|舅)([^居某早丧卒母妣諱曰也]{0,2})/',
              r'[公君吾夫人我/](三十一世祖|十八世祖|十六代祖|十五代祖|十三代祖|十二世祖|十二代祖|十一代祖|十一世祖|四代祖母|曾祖王父|外曾大父|外曾王父|外曾祖父|六代祖|十代祖|十世祖|九世祖|八世祖|七世祖|六世祖|五世祖|五代祖|四世祖|四代祖|高祖母|曾祖考|曾大父|大王父|曾王父|皇曾祖|曾大考|曾伯祖|曾叔祖|先祖考|先大父|先王父|皇祖考|伯祖父|叔祖父|從伯祖|再從伯|再從叔|再從舅|從伯父|從叔父|外祖父|外王父|外大父|外叔祖|外伯祖|再從舅|外伯父|外叔父|外大祖|外曾祖|遠祖|高祖|曾祖|先祖|大父|王父|大考|從祖|族祖|伯祖|叔祖|皇考|先父|先考|伯父|世父|叔父|族父|從伯|從父|從叔|從舅|外舅|母舅|外祖|從舅|外舅|祖|父|考|舅)([^居某早丧卒母妣諱曰也]{0,2}?)/',
              r'[公君吾夫人我/](三十一世祖|十八世祖|十六代祖|十五代祖|十三代祖|十二世祖|十二代祖|十一代祖|十一世祖|四代祖母|曾祖王父|外曾大父|外曾王父|外曾祖父|六代祖|十代祖|十世祖|九世祖|八世祖|七世祖|六世祖|五世祖|五代祖|四世祖|四代祖|高祖母|曾祖考|曾大父|大王父|曾王父|皇曾祖|曾大考|曾伯祖|曾叔祖|先祖考|先大父|先王父|皇祖考|伯祖父|叔祖父|從伯祖|再從伯|再從叔|再從舅|從伯父|從叔父|外祖父|外王父|外大父|外叔祖|外伯祖|再從舅|外伯父|外叔父|外大祖|外曾祖|遠祖|高祖|曾祖|先祖|大父|王父|大考|從祖|族祖|伯祖|叔祖|皇考|先父|先考|伯父|世父|叔父|族父|從伯|從父|從叔|從舅|外舅|母舅|外祖|從舅|外舅|祖|父|考|舅)([^居某早丧卒母妣諱曰也]{0,2}?)$',
              r'(三十一世祖|十八世祖|十六代祖|十五代祖|十三代祖|十二世祖|十二代祖|十一代祖|十一世祖|四代祖母|曾祖王父|外曾大父|外曾王父|外曾祖父|六代祖|十代祖|十世祖|九世祖|八世祖|七世祖|六世祖|五世祖|五代祖|四世祖|四代祖|高祖母|曾祖考|曾大父|大王父|曾王父|皇曾祖|曾大考|曾伯祖|曾叔祖|先祖考|先大父|先王父|皇祖考|伯祖父|叔祖父|從伯祖|再從伯|再從叔|再從舅|從伯父|從叔父|外祖父|外王父|外大父|外叔祖|外伯祖|再從舅|外伯父|外叔父|外大祖|外曾祖|遠祖|其先|高祖|曾祖|先祖|大父|王父|大考|從祖|族祖|伯祖|叔祖|皇考|先父|先考|先君|伯父|世父|叔父|族父|從伯|從父|從叔|從舅|外舅|母舅|外祖|從舅|外舅|祖|父|考|舅)(某官{0,1}?)',
              r'(三十一世祖|十八世祖|十六代祖|十五代祖|十三代祖|十二世祖|十二代祖|十一代祖|十一世祖|四代祖母|曾祖王父|外曾大父|外曾王父|外曾祖父|六代祖|十代祖|十世祖|九世祖|八世祖|七世祖|六世祖|五世祖|五代祖|四世祖|四代祖|高祖母|曾祖考|曾大父|大王父|曾王父|皇曾祖|曾大考|曾伯祖|曾叔祖|先祖考|先大父|先王父|皇祖考|伯祖父|叔祖父|從伯祖|再從伯|再從叔|再從舅|從伯父|從叔父|外祖父|外王父|外大父|外叔祖|外伯祖|再從舅|外伯父|外叔父|外大祖|外曾祖|遠祖|其先|高祖|曾祖|先祖|大父|王父|大考|從祖|族祖|伯祖|叔祖|皇考|先父|先考|先君|伯父|世父|叔父|族父|從伯|從父|從叔|從舅|外舅|母舅|外祖|從舅|外舅|祖|父|考|舅)[諱|曰](.{0,2})$',
             ]

# %%
df_sent_comp.sample(3)
# Out:
#        content_id subject author  \
# 4559      5834136     真德秀    魏了翁
# 26829     5803672      王蔡     度正
# 3811      5888793      杜杲    劉克莊
#
#                                                     sent  \
# 4559         明年太夫人卒/wsep/十五年服闋/wsep/除寶謨閣待制知潭州/wsep/湖南安撫使
# 26829  明年秋/wsep/生來/wsep/且述其父之言曰/wm/‘吾母棄諸孤今六年/wsep/吾學無...
# 3811                                    曾大父圯/wsep/提舉江西常平
#
#                                                  content  \
# 4559   真公德秀，建寧浦城人也，字景元，後更希元。紹定六年十月，上始親萬機，凡在外服者不旬月間召用無...
# 26829  正以大帥長沙吴公之招訓導石室，遂寧譚生在二三子中，貌甚淳，禮甚恭。退閲其贄甚通，已而察其行，...
# 3811   公諱杲，字子昕。曾大父圯，提舉江西常平。大父鐸，知萬載縣，贈大中夫。父穎〔一〕，刑部郎中，贈...
#
#                                                sent_comp   nz     ns no_noc  \
# 4559   明年太夫人卒/wsep/十五年服闋/wsep//vno//no_noc/知/ns//wsep...  NaN  潭州#南安  寶謨閣待制
# 26829  明年秋/wsep/生來/wsep/且述其父之言曰/wm/‘吾母棄諸孤今六年/wsep/吾學無...  NaN    NaN     文學
# 3811                              曾大父圯/wsep//no_noc/江西常平  NaN    NaN     提舉
#
#        vno
# 4559     除
# 26829  NaN
# 3811   NaN

# %%
kin_list=[]
df_kin_extracted=pd.DataFrame()
for re_rule in re_rule_list:
    for index in tqdm(df_sent_comp.index):
        string=df_sent_comp.loc[index, 'sent_comp']
        content_id=df_sent_comp.loc[index, 'content_id']
        content=df_sent_comp.loc[index, 'content']
        author=df_sent_comp.loc[index, 'author']
        subj=df_sent_comp.loc[index, 'subject']
        kin_list_temp=re.findall(re_rule, string)
        if kin_list_temp!=[]:
            df_kin_extracted=pd.concat([pd.DataFrame([[index, content_id, content, 
                                                       author, subj, kin[0], kin[1]] 
                                                      for kin in kin_list_temp]), df_kin_extracted], ignore_index=True)
# Out:
# 100%|██████████| 57733/57733 [00:10<00:00, 5538.67it/s]
# 100%|██████████| 57733/57733 [00:14<00:00, 3852.30it/s]
# 100%|██████████| 57733/57733 [00:10<00:00, 5410.46it/s]
# 100%|██████████| 57733/57733 [00:07<00:00, 7969.66it/s]
# 100%|██████████| 57733/57733 [00:07<00:00, 7391.99it/s]
# 100%|██████████| 57733/57733 [00:06<00:00, 8634.78it/s]

# %%
df_kin_extracted.columns=['sent_comp_index', 'content_id', 'content', 'author', 'subject', 'kin', 'name']
df_kin_extracted.sample(3)
# Out:
#       sent_comp_index  content_id  \
# 5571            15558     5006139
# 4256            39981     5583286
# 3046            67024     5062593
#
#                                                 content author subject kin  \
# 5571  夫功加于時，《周官》藏于盟府；忠以奉上，馬史列于世家。蓋智勇之誕生，必在乎將相之族；慶靈之回...     楊億     石保興  王父
# 4256  馮顯字子容，始予識之上饒，方舉進士〔一〕，眉宇疏秀，議論衎衎，文采粲然，而運蹇不得志〔二〕。...    韓元吉     NaN  曾祖
# 3046  君諱良孺，字得之，姓薛氏，絳州正平人也。少孤，育於其叔父，是爲簡肅公。以公蔭，爲將作監主簿、...    歐陽修     薛良孺   祖
#
#      name
# 5571    □
# 4256
# 3046

# %%
for index in tqdm(df_kin_extracted.index):
    sent_comp_index = df_kin_extracted.loc[index, 'sent_comp_index']
    df_temp=df_sent_comp.loc[sent_comp_index][['sent', 'sent_comp', 'nz','ns','no_noc','vno']]
    df_kin_extracted.loc[index, 'sent']=df_temp['sent']
    df_kin_extracted.loc[index, 'sent_comp']=df_temp['sent_comp']
    df_kin_extracted.loc[index, 'nz']=df_temp['nz']
    df_kin_extracted.loc[index, 'ns']=df_temp['ns']
    df_kin_extracted.loc[index, 'no_noc']=df_temp['no_noc']
    df_kin_extracted.loc[index, 'vno']=df_temp['vno']
# Out:
# 100%|██████████| 8477/8477 [01:06<00:00, 128.02it/s]

# %%
df_kin_extracted.sample(3)
# Out:
#       sent_comp_index  content_id  \
# 3353            57452     5191974
# 8060            18194     8707392
# 7526            43382     5464649
#
#                                                 content author subject kin  \
# 3353  治平中，余爲海州懷仁令，而永康陳君，實佐余爲主簿。余與君皆少且壯，相得甚適。後六年，余以翰林...     曾布      陳愷  曾祖
# 8060  ［志蓋］大宋故王府君墓誌銘［志文］大宋贈秘書少監王府君墓誌銘并序朝散大夫、行尚書兵部員外郎、...     丁度     NaN  曾祖
# 7526  士有能自植立者，雖不暴白於功名富貴，而嗜詩書，事筆研，潛心師古聖賢，以所得道理推而信於朋友，...    胡松年      李遠  曾祖
#
#      name                               sent  \
# 3353   思遠     曾祖思遠/wsep/祖文授/wsep/父億/wsep/皆不仕
# 8060    傑           曾祖諱傑/wsep/器識雄遠/wsep/材略邃茂
# 7526   守則  曾祖諱守則/wsep/祖諱吉/wsep/父諱文/wsep/皆不獲仕
#
#                               sent_comp   nz   ns no_noc  vno
# 3353     曾祖思遠/wsep/祖文授/wsep/父億/wsep/皆不仕  NaN  NaN    NaN  NaN
# 8060           曾祖諱傑/wsep/器識雄遠/wsep/材略邃茂  NaN  NaN    NaN  NaN
# 7526  曾祖諱守則/wsep/祖諱吉/wsep/父諱文/wsep/皆不獲仕  NaN  NaN    NaN  NaN

# %%
df_kin_extracted[df_kin_extracted['name']!=''].sample(5)
# Out:
#       sent_comp_index  content_id  \
# 2584            14255     5077717
# 6051             5176     5775406
# 2780             3969     5888826
# 715             20019     5902764
# 6853            61106     5141157
#
#                                                 content author subject kin  \
# 2584  前闕宣德節度判官，不行。以所知薦，擢爲殿中丞，遷國子博士、尚書虞、比、駕部員外郎中、司農少卿...    祖無擇     NaN   祖
# 6051  曾祖世括，贈少師、開府儀同三司、嘉國公；祖令陞，贈金紫光禄大夫；考子英，故朝議大夫、秘閣修撰...    孫應時     NaN  曾祖
# 2780  理宗皇帝在位四十一年，景定甲子九月，召前禮部侍郎吴公赴行在。未至，踰月而帝上賓。新天子繼志述...    劉克莊      吳燧  大父
# 715   梅爲宣城著姓，國史有傳者，給事中諱詢，席殊寵於咸平；都官員外郎堯臣，扇盛名於嘉祐。自時厥後，...     吴潛     梅應奇   考
# 6853  治平元年五月六日，荆湖北路轉運判官、尚書屯田郎中劉君，年五十四，以官卒。三年，卜十月某日，葬...    王安石      劉牧   父
#
#      name                                               sent  \
# 2584   瓌懿        曾祖隱/wsep/祖瓌懿/wsep/并不仕/wsep/治《左氏春秋》/wsep/世其學
# 6051   世括  曾祖世括/wsep/贈少師/wsep/開府儀同三司/wsep/嘉國公/wsep/祖令陞/ws...
# 2780    宗                         曾大父璉〔二〕/wsep/大父宗/wsep/皆里耆儒
# 715     某                                         考某/wsep/妣某
# 6853   知禮                       及君父諱知禮/wsep/又不仕/wsep/而鄉人稱爲君子
#
#                                               sent_comp   nz   ns  \
# 2584        曾祖隱/wsep/祖瓌懿/wsep/并不仕/wsep/治《左氏春秋》/wsep/世其學  NaN  NaN
# 6051  曾祖世括/wsep//vno//no_noc//wsep//no_noc//wsep//ns...  NaN   嘉國
# 2780                         曾大父璉〔二〕/wsep/大父宗/wsep/皆里耆儒  NaN  NaN
# 715                                          考某/wsep/妣某  NaN  NaN
# 6853                       及君父諱知禮/wsep/又不仕/wsep/而鄉人稱爲君子  NaN  NaN
#
#                            no_noc  vno
# 2584                          NaN  NaN
# 6051  開府儀同三司#朝議大夫#秘閣修撰#少師#大夫#大夫#令  贈#故
# 2780                          NaN  NaN
# 715                           NaN  NaN
# 6853                          NaN  NaN

# %%
df_kin_extracted[df_kin_extracted['name']!=''].drop('sent_comp_index', axis=1).sort_values(by='content_id').to_excel('../output/df_qsw_kin_extracted_male.xlsx', encoding='utf8')

# %% [markdown]
# ### Female kinship extraction.

# %%
re_rule_list=[r'(外叔祖母|外伯祖母|曾祖母|曾祖妣|曾大母|曾王母|曾祖姑|大王母|從祖母|繼祖母|叔祖母|從祖姑|伯祖母|叔祖母|再從姑|從伯姑|外王母|外祖母|祖母|王母|大母|祖妣|祖姑|伯母|叔母|仲姑|從姑|皇妣|先妣|後母|繼母|嫡母|生母|庶母|族母|姨母|外姑|從妗|外姑|姑|母|妣|姨|姑)([^曰也].{0,20}?)氏',
              r'([始先早前首再次又後繼]?娶|取|配)(.{1,10}?)氏',
              r'(繼)([^母].{0,10}?)氏',
              r'(妻)(.{0,10}?)氏',
             ]

# %%
kin_list=[]
df_kin_extracted=pd.DataFrame()
for re_rule in re_rule_list:
    for index in tqdm(df_sent_comp.index):
        string=df_sent_comp.loc[index, 'sent_comp']
        content_id=df_sent_comp.loc[index, 'content_id']
        content=df_sent_comp.loc[index, 'content']
        author=df_sent_comp.loc[index, 'author']
        subj=df_sent_comp.loc[index, 'subject']
        kin_list_temp=re.findall(re_rule, string)
        if kin_list_temp!=[]:
            for kin_nm in kin_list_temp:
                if kin_nm[1]!='':
                    kin_nm=(kin_nm[0], kin_nm[1][-1])
                df_kin_extracted=pd.concat([pd.DataFrame([[index, content_id, content, author, subj, re_rule, kin_nm[0], kin_nm[1]]]), df_kin_extracted], ignore_index=True)
#                 else:
#                     print(string, kin_list_temp)
# Out:
# 100%|██████████| 57733/57733 [00:12<00:00, 4490.07it/s]
# 100%|██████████| 57733/57733 [00:14<00:00, 3924.90it/s]
# 100%|██████████| 57733/57733 [00:07<00:00, 7826.31it/s]
# 100%|██████████| 57733/57733 [00:07<00:00, 7848.70it/s]

# %%
df_kin_extracted.columns=['sent_comp_index', 'content_id', 'content', 'author', 'subject', 're_rule', 'kin', 'name']

# %%
df_kin_extracted.sample(10)
# Out:
#       sent_comp_index  content_id  \
# 2082            33203     5713869
# 59              57253     5216854
# 5143            15004     5045329
# 353             27011     5801872
# 4605            31218     5752737
# 2046            34118     5713611
# 670             67198     5062596
# 2476            23565     5840806
# 2572            21054     5889717
# 1399            48309     5331967
#
#                                                 content author subject  \
# 2082  嘉泰元年春，姜君子謙赴鍾離。既餞之，又爲考濠梁故迹，爲大篇以贈别，所以期之者甚遠也。明年冬初...     樓鑰      姜柄
# 59    治平二年五月丁亥，趙郡蘇軾之妻王氏，卒于京師。六月甲午，殯于京城之西。其明年六月壬午，葬於眉...     蘇軾  蘇軾妻、王弗
# 5143  東平呂公相我太宗、真宗垂二十年。咸平六年夏，以疾罷歸第。大中祥符四年四月十九日，遂不起，年六...     富弼     呂蒙正
# 353   今尚書度支郎中趙君必愿之妻宜人湯氏，金壇人。曾祖鵬舉，皇任資政殿學士、大中大夫，贈宣奉大夫，...     劉宰     湯邦彦
# 4605  公諱坰，字卿遠，明之鄞人也。曾大父諱揆，贈太中大夫，妣施氏，旌德縣君。大父諱轂，左朝奉大夫、...     袁燮      袁坰
# 2046  公諱宗質，字文叔，世家于濮。六世祖文定公相真宗、仁宗，隱然爲社稷臣。子太子少師柬之諡懿靖，又...     樓鑰     李宗質
# 670   太子少師致仕、贈太子太傅胡公諱宿，字武平。其先豫章人也，後徙常州之晋陵，世有隱德，爲晋陵著姓...    歐陽修      胡宿
# 2476  公姓葉氏，諱文炳，字晦叔。世家河南，後有以客省使刺泉州者，過浦城，睹山川秀異，因居焉。曾大父...    真德秀     葉文炳
# 2572  余晚起家爲詞臣，趙君慶龍自淮左捧檄入都，請予銘其先君子野塘處士之墓。余已耄昏，又禁中書詔填委...    劉克莊      趙遂
# 1399  隱君任某，字某，遂之小谿人。曾祖、祖父皆韜翳於德，亡肯出仕者。君性安静，静而介，介而通，通而...     李新     NaN
#
#                                                 re_rule  kin name
# 2082                    ([始先早前首再次又後繼]?娶|取|配)(.{1,10}?)氏    娶    魏
# 59                                       (妻)(.{0,10}?)氏    妻    王
# 5143  (外叔祖母|外伯祖母|曾祖母|曾祖妣|曾大母|曾王母|曾祖姑|大王母|從祖母|繼祖母|叔祖母...  曾王母    王
# 353                                  (繼)([^母].{0,10}?)氏    繼    鄧
# 4605  (外叔祖母|外伯祖母|曾祖母|曾祖妣|曾大母|曾王母|曾祖姑|大王母|從祖母|繼祖母|叔祖母...    妣    石
# 2046                    ([始先早前首再次又後繼]?娶|取|配)(.{1,10}?)氏    娶    夏
# 670                     ([始先早前首再次又後繼]?娶|取|配)(.{1,10}?)氏   再娶    何
# 2476                    ([始先早前首再次又後繼]?娶|取|配)(.{1,10}?)氏    娶    張
# 2572                    ([始先早前首再次又後繼]?娶|取|配)(.{1,10}?)氏    配    俞
# 1399                    ([始先早前首再次又後繼]?娶|取|配)(.{1,10}?)氏    娶    劉

# %%
for index in tqdm(df_kin_extracted.index):
    sent_comp_index = df_kin_extracted.loc[index, 'sent_comp_index']
    df_temp=df_sent_comp.loc[sent_comp_index][['sent', 'sent_comp', 'nz','ns','no_noc','vno']]
    df_kin_extracted.loc[index, 'sent']=df_temp['sent']
    df_kin_extracted.loc[index, 'sent_comp']=df_temp['sent_comp']
    df_kin_extracted.loc[index, 'nz']=df_temp['nz']
    df_kin_extracted.loc[index, 'ns']=df_temp['ns']
    df_kin_extracted.loc[index, 'no_noc']=df_temp['no_noc']
    df_kin_extracted.loc[index, 'vno']=df_temp['vno']
# Out:
# 100%|██████████| 5844/5844 [00:41<00:00, 140.78it/s]

# %%
len(df_kin_extracted[df_kin_extracted['name']!=''])
# Out:
# 5844

# %%
df_kin_extracted[df_kin_extracted['name']!='']\
.drop(['sent_comp_index'],axis=1)\
.sort_values(by='content_id')\
.to_excel('../output/df_qsw_kin_extracted_female.xlsx', encoding='utf8')

# %% [markdown]
# ### Son/Daughter kinship extraction.

# %% [markdown]
# #### TODO:
# need to be splited.
# - [^第][一二三四五六七八九十][男|子][^女孫].{0,150} 1566  有效比例應該有一半左右。需加入
# - [^子孫孙]男(.{0,3}?)人.{0,50} 112 需加入
# - (子|孫|曾孫|曾孫男|男|孫男|子男|孙男|孙)[一二三四五六七八九十]/  311 需加入
#
# No need to be splited - results messy.
# - (其兄|其弟|長兄|次兄|長弟|次弟|季兄|幼弟|同母弟|仲父|堂兄|從兄|從弟|堂弟|再從兄|從堂兄|再從弟|再從兄弟|再從昆弟|族兄|族弟|姊夫|元昆|亞弟|季弟|季兄|仲兄|仲弟|叔弟|妻兄|妻弟|嗣子|長子|次子|仲子|幼子|少子|庶子|伯子|仲子|季子|長婿|次婿|侄|侄子|從子|堂侄|再從子|再從姪|侄女婿|甥|孫|孫男|男孫|曾孫|曾孫男|曾姪孫|曾孫婿|外曾孫|玄孫|四世孫|來孫|第二子|第三子|第四子|第五子|第六子|第七子|第八子|第十子|第十三子|婿|妹婿|再從孫|孫婿|孫女婿|外孫|外孫男|姪孫|嫡孫|長孫|從孫|外甥|妻甥|甥男)[\w|\/]+.{0,2} 101新增
# - (其兄|其弟|長兄|次兄|長弟|次弟|季兄|幼弟|同母弟|仲父|堂兄|從兄|從弟|堂弟|再從兄|從堂兄|再從弟|再從兄弟|再從昆弟|族兄|族弟|姊夫|元昆|亞弟|季弟|季兄|仲兄|仲弟|叔弟|妻兄|妻弟|嗣子|長子|次子|仲子|幼子|少子|庶子|伯子|仲子|季子|長婿|次婿|侄|侄子|從子|堂侄|再從子|再從姪|侄女婿|甥|孫|孫男|男孫|曾孫|曾孫男|曾姪孫|曾孫婿|外曾孫|玄孫|四世孫|來孫|第二子|第三子|第四子|第五子|第六子|第七子|第八子|第十子|第十三子|婿|妹婿|再從孫|孫婿|孫女婿|外孫|外孫男|姪孫|嫡孫|長孫|從孫|外甥|妻甥|甥男)/no_noc/.{0,2} 238新增

# %%
re_rule_list=[r'(曾孫男|孫男|子男|孙男|曾孫|子|孫|孙|男|女|婿)曰([^/]+?)\/',
              r'(子男)(.{0,3}?)人(\/.+)',
              r'([^女]*曾孫|孫)([^女]{0,3}?)人(\/.+)',
              r'([^女]*孫子|子)([^男女]{0,3}?)人(\/.+)',
             ]

# %%
kin_list=[]
df_kin_extracted=pd.DataFrame()
list_temp=[]
for re_rule in re_rule_list:
    for index in tqdm(df_sent_comp.index):
        string=df_sent_comp.loc[index, 'sent_comp']
        content_id=df_sent_comp.loc[index, 'content_id']
        content=df_sent_comp.loc[index, 'content']
        author=df_sent_comp.loc[index, 'author']
        subj=df_sent_comp.loc[index, 'subject']
        kin_list_temp=re.findall(re_rule, string)
        if kin_list_temp!=[]:
            for kin_nm in kin_list_temp:
                if len(kin_nm)==2:
                    kin_nm=(kin_nm[0], '', kin_nm[1])
                df_kin_extracted=pd.concat([pd.DataFrame([list(kin_nm)+[re_rule, string, content_id, content, author, subj]]), 
                                            df_kin_extracted], ignore_index=True)
                list_temp.append(kin_nm)
# Out:
# 100%|██████████| 57733/57733 [00:08<00:00, 6835.71it/s]
# 100%|██████████| 57733/57733 [00:09<00:00, 6265.05it/s]
# 100%|██████████| 57733/57733 [00:14<00:00, 4100.84it/s]
# 100%|██████████| 57733/57733 [00:11<00:00, 4907.17it/s]

# %%
df_kin_extracted.sample(3)
# Out:
#       0  1                                                  2  \
# 3041  男                                                  珪〔一〕
# 702   子  二  /wm/庶/wsep//no_noc//wsep/改差知/ns//wsep/廡/wsep//...
# 678   子  九  /wm/鐊/wsep//no_noc//wsep//ns/績谿/no_noc//wsep/錫...
#
#                                              3  \
# 3041  (曾孫男|孫男|子男|孙男|曾孫|子|孫|孙|男|女|婿)曰([^/]+?)\/
# 702            ([^女]*孫子|子)([^男女]{0,3}?)人(\/.+)
# 678            ([^女]*孫子|子)([^男女]{0,3}?)人(\/.+)
#
#                                                       4        5  \
# 3041                                    男曰珪〔一〕/wsep/女未名  5801812
# 702   子二人/wm/庶/wsep//no_noc//wsep/改差知/ns//wsep/廡/wse...  5888793
# 678   子九人/wm/鐊/wsep//no_noc//wsep//ns/績谿/no_noc//wse...  5713244
#
#                                                       6    7    8
# 3041  嘉定丁丑十一月丙申，廣西經略安撫司幹辦公事、同措置買馬范君克信卒於官，得年六十有九。明年七月...   劉宰  范克信
# 702   公諱杲，字子昕。曾大父圯，提舉江西常平。大父鐸，知萬載縣，贈大中夫。父穎〔一〕，刑部郎中，贈...  劉克莊   杜杲
# 678   亡妣姓汪氏，諱慧通，字正柔，明之鄞人。曾祖元吉不仕，祖洙，明州助教，累贈正奉大夫。父思温，左...   樓鑰  NaN

# %%
df_kin_extracted=df_kin_extracted.rename(columns={0:'kin', 1:'number', 2:'name_string', 
                                                  3:'re_rule', 4:'sent_comp', 5:'content_id',
                                                  6:'content', 7:'author', 8:'subj'})

# %%
del_dict=['皆其婿也','季曰','伯曰','仲曰','叔曰','次即','及第','中第',
          '中舉','今以','今爲','江淮','兩浙','某官','税務','支鹽',
          '士族','士人','許嫁','許適','許歸','未冠','未仕','未官',
          '未命','先歿','先亡','先公','早夭','早亡','早世','尚幼',
          '未名','前卒','先卒','蚤卒','俱有','早卒','早喪','一人',
          '二人','一尚','二尚','三尚','三女','三人','三曰','四人',
          '四先','四女','未仕','未銓','左銓','司户','户部','長',
          '次','幼','曰','即','也','貢','等','第','登','科','今',
          '授','事','都','轄','新','知','舊','監','倉','庫','起',
          '終','故','前','後','左','右','州','軍','路','郡','縣',
          '府','寺','尉','官','俱','業','業','習','適','嫁','歸',
          '許','皆','並','并','餘','俱','竝','未','夭','卒','幼',
          '尚','早','喪','一','二','三','户',]

# %%
def clean_name_string(name_string):
    global del_dict
    name_string_list=[s for s in re.sub(r'[a-z_]', '', name_string).split('/') if s!='']
    name_string_list_refined=[]
    for name_string in name_string_list:
        for del_string in del_dict:
            name_string=name_string.replace(del_string, '')
        if name_string!='' and len(name_string)<=2:
            name_string_list_refined.append(name_string)
    return name_string_list_refined

# %%
df_kin_extracted['name_string']=[clean_name_string(s) for s in df_kin_extracted['name_string']]
df_kin_extracted.sample(3)
# Out:
#      kin number              name_string                          re_rule  \
# 1179  曾孫      六                     [撙之]   ([^女]*曾孫|孫)([^女]{0,3}?)人(\/.+)
# 482    子      二                 [慶臣, 清臣]  ([^女]*孫子|子)([^男女]{0,3}?)人(\/.+)
# 2489  子男      四  [炳文, 已, 夢得, 思義, 發解, 夢符]             (子男)(.{0,3}?)人(\/.+)
#
#                                               sent_comp  content_id  \
# 1179               曾孫六人/wsep/曰撙之/wsep//no_noc//wsep/餘尚幼     5459896
# 482                                 子二人/wsep/慶臣/wsep/清臣     5770429
# 2489  子男四人/wm/長炳文/wsep/已卒/wsep/次夢得/wsep/以後伯氏/wsep/凡再...     5834653
#
#                                                 content author subj
# 1179  紹興八年春，右朝議大夫、廣南東路轉運判官高君公軒奉母夫人北歸，寓居吉州之具慶坊[sub]〔一...    劉才邵  NaN
# 482   余爲令臨川，愛其山川風俗之媺，名儒鉅公彬彬輩出，故家遺俗皆知尚氣節、畏清議，信厚而質直，其天...     黄榦  黄思永
# 2489  孫氏之先居青社。七世祖鐐，咸平中主江陵石首簿，卒官，葬紀山皇華原，遂爲江陵人〔一〕。至四世羲...    魏了翁   孫堪

# %%
df_kin_extracted.to_excel('../output/df_kin_extracted_son_dau_etc.xlsx', encoding='utf8')

# %% [markdown]
# ### Son in law.
# TODO:
# - [ ] similar to Son.
# - [ ] Name length: 2-3.
#
# Regular expression rules:
# - (孫女|女|曾孫女)[許適嫁歸].{1,200}  464 如何表达呢
# - (一女|二女|三女|四女|五女|六女|七女|八女|九女|十女|十一女|十六女).{0,50}?[許適嫁歸]  913
# - (曾孫女|孫女|女|女孫|妹).{0,2}人.{0,50}?[許適嫁歸] 1368
# - (孫女|女|曾孫女)[一二三四五六七八九十]/   198
# - (姑|同母姊|姊|妹|堂姊|堂妹|再從妹|再從姊|表妹|表姊|仲女|長女|次女|幼女|季女|甥女|表甥|表甥女|從孫女|孫婦|外甥女|曾孫女|外孫女|姪孫女|甥女)[^一二三四五六七八九十].{1,50}?[適嫁歸] 207

# %%
re_rule_list=[r'(曾孫女|孫女|女)[許適嫁歸](.{1,200})',
              r'(十一女|十六女|一女|二女|三女|四女|五女|六女|七女|八女|九女|十女).{0,50}?[許適嫁歸](.+?)',
              r'(曾孫女|孫女|女孫|女|妹).{0,2}人.{0,50}?[許適嫁歸](.+?)',
              r'(曾孫女|孫女|女孫|女|妹)[一二三四五六七八九十]/(.+?)', # Some records are not about son in law but daughters' name.
              r'(再從妹|再從姊|外甥女|曾孫女|外孫女|姪孫女|表甥女|從孫女|同母姊|堂姊|堂妹|表妹|表姊|仲女|長女|次女|幼女|季女|甥女|表甥|孫婦|甥女|姑|姊|妹)[^一二三四五六七八九十].{1,50}?[適嫁歸](.+?)',
             ]

# %%
kin_list=[]
df_kin_extracted=pd.DataFrame()
list_temp=[]
for re_rule in re_rule_list:
    for index in tqdm(df_sent_comp.index):
        string=df_sent_comp.loc[index, 'sent_comp']
        content_id=df_sent_comp.loc[index, 'content_id']
        content=df_sent_comp.loc[index, 'content']
        author=df_sent_comp.loc[index, 'author']
        subj=df_sent_comp.loc[index, 'subject']
        kin_list_temp=re.findall(re_rule, string)
        if kin_list_temp!=[]:
            for kin_nm in kin_list_temp:
                df_kin_extracted=pd.concat([pd.DataFrame([list(kin_nm)+[re_rule, string, content_id, content, author, subj]]), 
                                            df_kin_extracted], ignore_index=True)
                list_temp.append(kin_nm)
# Out:
# 100%|██████████| 57733/57733 [00:09<00:00, 6396.63it/s]
# 100%|██████████| 57733/57733 [00:10<00:00, 5292.73it/s]
# 100%|██████████| 57733/57733 [00:13<00:00, 4134.86it/s]
# 100%|██████████| 57733/57733 [00:24<00:00, 2316.19it/s]
# 100%|██████████| 57733/57733 [00:08<00:00, 6560.21it/s]

# %%
df_kin_extracted.sample(3)
# Out:
#        0            1                                                  2  \
# 4896  三女            宗  (一女|二女|三女|四女|五女|六女|七女|八女|九女|十女|十一女|十六女).{0,50}...
# 111    姑            于  (姑|同母姊|姊|妹|堂姊|堂妹|再從妹|再從姊|表妹|表姊|仲女|長女|次女|幼女|季女|...
# 5484   女  /no_noc/周景南                         (孫女|女|曾孫女)[許適嫁歸](.{1,200})
#
#                                                       3        4  \
# 4896                            三女/wsep/長嫁宗室崇譓/wsep/二尚幼  5764623
# 111   今吾外姑之葬/wsep/雖微諸孤之請/wsep/吾敢無銘乎?外姑踰笄/wsep/歸于外舅/w...  5731174
# 5484  娶陳氏/wsep/生文與方及一女而卒/wsep/及見方/vno//no_noc//wsep/...  5784081
#
#                                                       5    6    7
# 4896  嗚呼，學之難也!質與性不合，年與人不並，幼而教之，時至而不得成其材，十且八九也，況不幸失教者...   葉適  丁希亮
# 111   余少時見墓銘日多，往往緣稱美之義，不復顧其實，侈言溢辭，使人無取信。竊念之曰：‘苟如是，不如...  陸九淵  NaN
# 5484  梅坡先生之喪，當有銘以納諸壙。其子方會稡行實，乃以屬諸某，謹論次其事。先生諱蠡，字師范，避大...  曹彦約  彭蠡、

# %%
df_kin_extracted=df_kin_extracted.rename(columns={0:'kin', 1:'name_string', 
                                                  2:'re_rule', 3:'sent_comp', 4:'content_id',
                                                  5:'content', 6:'author', 7:'subj'})

# %%
df_kin_extracted.sample(3)
# Out:
#      kin                name_string  \
# 5161   女  /vno//no_noc/劉庠/wsep/次女在室
# 3329   女                          /
# 2059   女                          人
#
#                                         re_rule  \
# 5161                 (孫女|女|曾孫女)[許適嫁歸](.{1,200})
# 3329  (曾孫女|孫女|女|女孫|妹).{0,2}人.{0,50}?[許適嫁歸](.+?)
# 2059                (孫女|女|曾孫女)[一二三四五六七八九十](.+?)
#
#                                               sent_comp  content_id  \
# 5161                       長女適/vno//no_noc/劉庠/wsep/次女在室     5017311
# 3329  女子七人/wm/適/no_noc/焦莊叔/wsep/修/ns/趙叔蘧/wsep//no_no...     5296548
# 2059  女二人/wsep/長適/no_noc/費伯午/wsep/次適/no_noc//wsep/監/...     5834753
#
#                                                 content author subj
# 5161  寶元二年，歲次己卯，四月，前參知政事、户部侍郎蔡公薨，天子悼之，卿大夫憂之，國人傷之。上命三...    范仲淹   蔡齊
# 3329  　　公諱公述，字傳之，丞相文元公之孫，尚書駕部員外郎、贈右光禄大夫諱田之子也。文元公以經術勳...     王寔  NaN
# 2059  慶元末，予試吏西川幕府，與郭君幼才爲僚。暨守眉，幼才爲青神宰，戢姦弭訟，崇學厲俗，有治理聲，...    魏了翁  郭叔誼

# %%
del_dict=['皆其婿也','季曰','伯曰','仲曰','叔曰','次即','及第','中第',
          '中舉','今以','今爲','江淮','兩浙','某官','税務','支鹽',
          '士族','士人','許嫁','許適','許歸','未冠','未仕','未官',
          '未命','先歿','先亡','先公','早夭','早亡','早世','尚幼',
          '未名','前卒','先卒','蚤卒','俱有','早卒','早喪','一人',
          '二人','一尚','二尚','三尚','三女','三人','三曰','四人',
          '四先','四女','未仕','未銓','左銓','司户','户部','長',
          '次','幼','曰','即','也','貢','等','第','登','科','今',
          '授','事','都','轄','新','知','舊','監','倉','庫','起',
          '終','故','前','後','左','右','州','軍','路','郡','縣',
          '府','寺','尉','官','俱','業','業','習','適','嫁','歸',
          '許','皆','並','并','餘','俱','竝','未','夭','卒','幼',
          '尚','早','喪','一','二','三','户',]

# %%
def clean_name_string(name_string):
    global del_dict
    name_string_list=[s for s in re.sub(r'[a-z_]', '', name_string).split('/') if s!='']
    name_string_list_refined=[]
    for name_string in name_string_list:
        for del_string in del_dict:
            name_string=name_string.replace(del_string, '')
        if name_string!='' and len(name_string)<=2:
            name_string_list_refined.append(name_string)
    return name_string_list_refined

# %%
df_kin_extracted['name_string']=[clean_name_string(s) for s in df_kin_extracted['name_string']]
df_kin_extracted.sample(3)

# %%
df_kin_extracted.to_excel('../output/df_kin_extracted_son_in_law.xlsx', encoding='utf8')

# %% [markdown]
# ### TODO:
#
# 捡漏型，需要填空
#
# - 中间为关系，连接前后两个人名，有两种形式：某，某之子也。某之子某。在此进行了合并查找。
# - .{1,3}?之(兄|弟|長兄|次兄|長弟|次弟|季兄|幼弟|同母弟|仲父|堂兄|從兄|從弟|堂弟|再從兄|從堂兄|再從弟|再從兄弟|再從昆弟|族兄|族弟|姊夫|元昆|亞弟|季弟|季兄|仲兄|仲弟|叔弟|妻兄|妻弟|嗣子|長子|次子|仲子|幼子|少子|庶子|伯子|仲子|季子|長婿|次婿|侄|侄子|從子|堂侄|再從子|再從姪|侄女婿|甥|孫|孫男|男孫|曾孫|曾孫男|曾姪孫|曾孫婿|外曾孫|玄孫|四世孫|來孫|第二子|第三子|第四子|第五子|第六子|第七子|第八子|第十子|第十三子|婿|妹婿|再從孫|孫婿|孫女婿|外孫|外孫男|姪孫|嫡孫|長孫|從孫|外甥|妻甥|甥男|冢婦|仲子婦姑|同母姊|姊|妹|堂姊|堂妹|再從妹|再從姊|表妹|表姊|長女|仲女|次女|幼女|季女|甥女|表甥|表甥女|從孫女|孫婦|外甥女|曾孫女|外孫女|姪孫女|甥女|遠祖|三十一世祖|十八世祖|十六代祖|十五代祖|十三代祖|十二世祖|十二代祖|六代祖|十代祖|十一代祖|十一世祖|十世祖|九世祖|八世祖|七世祖|六世祖|五世祖|五代祖|高祖|四世祖|四代祖|高祖母|四代祖母|曾祖|曾祖考|曾大父|大王父|曾王父|曾祖王父|皇曾祖|曾大考|曾伯祖|曾叔祖|先祖|先祖考|先大父|先王父|大父|王父|皇祖考|大考|祖|從祖|族祖|伯祖|伯祖父|叔祖父|叔祖|從伯祖|父|考|皇考|先父|先考|伯父|世父|叔父|族父|再從伯|再從叔|再從舅|從伯|從父|從伯父|從叔|從叔父|從舅|外舅|母舅|外曾大父|外曾王父|外曾祖父|外祖|外祖父|外王父|外大父|外叔祖|外伯祖|舅|從舅|再從舅|外舅|舅|外伯父|外叔父|外大祖|外曾祖|曾祖母|曾祖妣|曾大母|曾王母|曾祖姑|祖母|王母|大王母|大母|祖妣|從祖母|外叔祖母|繼祖母|叔祖母|祖姑|從祖姑|伯祖母|叔祖母|伯母|叔母|姑|仲姑|從姑|母|妣|皇妣|先妣|後母|繼母|嫡母|生母|庶母|再從姑|從伯姑|族母|姨母|姨|外姑|外王母|外祖母|外伯祖母|從妗|外姑|姨|姑|子|女)曰?.{0,2}
# - 4890 新增
